# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load

# %%
# %cd '/content/drive/MyDrive/19_5_Results/LOAD/Lags_only'
# Out:
# /content/drive/MyDrive/19_5_Results/LOAD/Lags_only

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Đọc dữ liệu từ file pickle
def load_data(file_path):
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    return data

data_method1 = load_data('Autoreg_GradientBoostingtree_lags_only.pkl')
data_method2 = load_data('Autoreg_RandomForest_lags_only.pkl')
data_method3 = load_data('Autoreg_HistGradientBoostingTree_lags_only.pkl')
data_method4 = load_data('Autoreg_KNN_lags_only.pkl')
data_method5 = load_data('Autoreg_MLP_lags_only.pkl')
data_method6 = load_data('Autoreg_Ridge_lags_only.pkl')
data_method7 = load_data('Autoreg_XGBoost_lags_only.pkl')

# Tạo bảng so sánh lỗi
methods = ['GradientBoostingtree', 'Random_Forest','HistGradientboosting',
           'KNN','MLP','Ridge','XGBoost']
rmse = [data_method1['RMSE'], data_method2['RMSE'],
        data_method3['RMSE'], data_method4['RMSE'],
        data_method5['RMSE'], data_method6['RMSE'], 
        data_method7['RMSE']]

mse = [data_method1['MSE'], data_method2['MSE'],
       data_method3['MSE'], data_method4['MSE'],
       data_method5['MSE'], data_method6['MSE'], 
       data_method7['MSE']]

mae = [data_method1['MAE'], data_method2['MAE'],
       data_method3['MAE'], data_method4['MAE'],
       data_method5['MAE'], data_method6['MAE'], 
       data_method7['MAE']] 

rel_mae =[data_method1['Relative MAE'], data_method2['Relative MAE'],
          data_method3['Relative MAE'], data_method4['Relative MAE'],
          data_method5['Relative MAE'], data_method6['Relative MAE'], 
          data_method7['Relative MAE']]

rel_rmse =[data_method1['Relative RMSE'], data_method2['Relative RMSE'],
           data_method3['Relative RMSE'], data_method4['Relative RMSE'],
           data_method5['Relative RMSE'], data_method6['Relative RMSE'], 
           data_method7['Relative RMSE']]

train_time =[data_method1['train time'], data_method2['train time'],
             data_method3['train time'], data_method4['train time'],
             data_method5['train time'], data_method6['train time'], 
             data_method7['train time']]

test_time = [data_method1['test time'], data_method2['test time'],
             data_method3['test time'], data_method4['test time'],
             data_method5['test time'], data_method6['test time'], 
             data_method7['test time']]


df_rank = pd.DataFrame({
    'Method': methods,
    'MAE error ': mae,
    'Relative mae error (%)': rel_mae,
    'RRMSE error': rmse,
    'Relative mse error (%)': rel_rmse,
    'train time': train_time,
    'test time': test_time

})

print(df_rank)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree   16.634596                6.771020    23.750509
# 1         Random_Forest   17.060306                6.944303    24.562576
# 2  HistGradientboosting   16.632390                6.770122    24.150952
# 3                   KNN   22.228271                9.047895    29.765597
# 4                   MLP   16.206737                6.596863    23.052962
# 5                 Ridge   15.942736                6.489402    22.913717
# 6               XGBoost   17.079151                6.951974    24.184507
#
#    Relative mse error (%)  train time   test time
# 0                9.667513   70.000249  428.505574
# 1                9.998061  102.402581  634.513317
# 2                9.830511   32.018342  232.095534
# 3               12.115922    2.637972   16.575755
# 4                9.383581   37.800401  212.562109
# 5                9.326902    0.070179    1.346873
# ...

# %%
# %cd '/content/drive/MyDrive/19_5_Results/LOAD/Lags_and_exog'
# Out:
# /content/drive/MyDrive/19_5_Results/LOAD/Lags_and_exog

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Đọc dữ liệu từ file pickle
def load_data(file_path):
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    return data

data_method1 = load_data('Autoreg_GradientBoostingtree_lags_and_exog.pkl')
data_method2 = load_data('Autoreg_RandomForest_lags_and_exog.pkl')
data_method3 = load_data('Autoreg_HistGradientBoostingTree_lags_and_exog.pkl')
data_method4 = load_data('Autoreg_KNN_lags_and_exog.pkl')
data_method5 = load_data('Autoreg_MLP_lags_and_exog.pkl')
data_method6 = load_data('Autoreg_Ridge_lags_and_exog.pkl')
data_method7 = load_data('Autoreg_XGBoost_lags_and_exog.pkl')

# Tạo bảng so sánh lỗi
methods = ['GradientBoostingtree', 'Random_Forest','HistGradientboosting',
           'KNN','MLP','Ridge','XGBoost'
           ]
rmse = [data_method1['RMSE'], data_method2['RMSE'],
        data_method3['RMSE'], data_method4['RMSE'],
        data_method5['RMSE'], data_method6['RMSE'], 
        data_method7['RMSE']]

mse = [data_method1['MSE'], data_method2['MSE'],
       data_method3['MSE'], data_method4['MSE'],
       data_method5['MSE'], data_method6['MSE'], 
       data_method7['MSE']]

mae = [data_method1['MAE'], data_method2['MAE'],
       data_method3['MAE'], data_method4['MAE'],
       data_method5['MAE'], data_method6['MAE'], 
       data_method7['MAE']]

rel_mae =[data_method1['Relative MAE'], data_method2['Relative MAE'],
          data_method3['Relative MAE'], data_method4['Relative MAE'],
          data_method5['Relative MAE'], data_method6['Relative MAE'], 
          data_method7['Relative MAE']]

rel_rmse =[data_method1['Relative RMSE'], data_method2['Relative RMSE'],
           data_method3['Relative RMSE'], data_method4['Relative RMSE'],
           data_method5['Relative RMSE'], data_method6['Relative RMSE'], 
           data_method7['Relative RMSE']]

train_time =[data_method1['train time'], data_method2['train time'],
             data_method3['train time'], data_method4['train time'],
             data_method5['train time'], data_method6['train time'], 
             data_method7['train time']]

test_time = [data_method1['test time'], data_method2['test time'],
             data_method3['test time'], data_method4['test time'],
             data_method5['test time'], data_method6['test time'], 
             data_method7['test time']]


df_rank2 = pd.DataFrame({
    'Method': methods,
    'MAE error ': mae,
    'Relative mae error (%)': rel_mae,
    'RRMSE error': rmse,
    'Relative mse error (%)': rel_rmse,
    'train time': train_time,
    'test time': test_time

})

print(df_rank2)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree   16.523698                6.725880    24.349846
# 1         Random_Forest   16.487757                6.711250    23.910216
# 2  HistGradientboosting   16.971994                6.908356    25.247510
# 3                   KNN   21.725892                8.843404    29.309326
# 4                   MLP   16.360105                6.659290    23.533301
# 5                 Ridge   15.513716                6.314772    22.600196
# 6               XGBoost   16.340010                6.651111    23.392272
#
#    Relative mse error (%)  train time   test time
# 0                9.911470  103.261295  609.773989
# 1                9.732521  110.266726  653.405962
# 2               10.276859    4.590780   33.917335
# 3               11.930199    1.950475   15.224718
# 4                9.579100   12.290655   72.488396
# 5                9.199285   17.482792  101.270005
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
target = 'load demand'
# Tạo bảng màu thủ công
palette = {
    'GradientBoostingtree': 'blue',
    'Random_Forest': 'red',
    'HistGradientboosting': 'green',
    'KNN': 'pink',
    'MLP': 'orange',
    'Ridge': 'brown',
    'XGBoost': 'purple',
    'CatBoosting': 'black'
}

plt.figure(figsize=(10, 7))

# Vẽ các scatterplot
sns.scatterplot(data=df_rank, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend='full')
sns.scatterplot(data=df_rank2, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend=False)


# Đặt tên cho trục và tiêu đề đồ thị
plt.xlabel("Running Time (s)", size=20)
plt.ylabel("Relative Error (MAE) %", size=20)
plt.title("Error vs Testing Time for " + target + " Forecast in 24 hours", size=20)

# Thêm chú thích tùy chỉnh ngắn gọn cho các kiểu marker
plt.scatter([], [], c='cyan', marker='o', label='lags+exog')
plt.scatter([], [], c='cyan', marker='X', label='lags only')

# Hiển thị chú thích với cỡ chữ nhỏ hơn
plt.legend(title="Markers", fontsize=10, title_fontsize=12, loc='upper right')
plt.xlim(-200,4000)
plt.ylim(5,12)
# Hiển thị đồ thị
plt.show()
# Out:
# <ipython-input-25-80f9ee8c8356>:19: UserWarning:
# The markers list has fewer values (1) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend='full')
# <ipython-input-25-80f9ee8c8356>:20: UserWarning:
# The markers list has fewer values (1) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank2, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Tạo bảng màu thủ công để áp dụng cho tất cả các lần gọi scatterplot
palette = {
    'GradientBoostingtree': 'blue',
    'Random_Forest': 'red',
    'HistGradientboosting': 'green',
    'KNN': 'pink',
    'MLP': 'orange',
    'Ridge': 'brown',
    'XGBoost': 'purple',
    'CatBoosting': 'black'
}

plt.figure(figsize=(10, 7))

# Vẽ các scatterplot
sns.scatterplot(data=df_rank, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend="full")
sns.scatterplot(data=df_rank2, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend=False)

# Đặt tên cho trục và tiêu đề đồ thị
plt.xlabel("Running Time (s)", size=20)
plt.ylabel("Relative Error (RMSE) %", size=20)
plt.title("Error vs Testing Time for " + target + " Forecast in 24 hours", size=20)

# Thêm chú thích tùy chỉnh ngắn gọn cho các kiểu marker
plt.scatter([], [], c='black', marker='o', label='lags+exog')
plt.scatter([], [], c='black', marker='X', label='lags only')

# Hiển thị chú thích với cỡ chữ nhỏ hơn
plt.legend(title="Markers", fontsize=10, title_fontsize=12, loc='upper right')
plt.xlim(-200,4000)
plt.ylim(8,14)
# Hiển thị đồ thị
plt.show()
# Out:
# <ipython-input-27-5317fdf602e0>:19: UserWarning:
# The markers list has fewer values (1) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend="full")
# <ipython-input-27-5317fdf602e0>:20: UserWarning:
# The markers list has fewer values (1) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank2, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend=False)

# %%
import pandas as pd

# Giả sử bạn có một DataFrame với cột thời gian tính bằng giây

df_rank = pd.DataFrame(df_rank)

# Tạo cột phút và giây
df_rank['minutes'] = df_rank['train time'] // 60
df_rank['seconds'] = (df_rank['train time'] % 60).astype(int)

df_rank['converted train time'] = df_rank['minutes'].astype(str) + 'p:' + df_rank['seconds'].astype(str).str.zfill(2) + 's'

# Hiển thị kết quả
print(df_rank)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree   18.261076                6.856901    25.742938
# 1         Random_Forest   17.676717                6.637478    25.233405
# 2  HistGradientboosting   18.578334                6.976029    26.445477
# 3                   KNN   23.595346                8.859881    31.618577
# 4                   MLP   17.261067                6.481405    24.370805
# 5                 Ridge   20.480553                7.690299    28.229876
# 6               XGBoost   18.593861                6.981859    26.908556
# 7           CatBoosting   15.970150                5.996675    23.694468
#
#    Relative mse error (%)  train time    test time  minutes  seconds  \
# 0                9.666286   28.681045   793.686504      0.0       28
# 1                9.474960  180.296633  4478.752779      3.0        0
# 2                9.930084   56.953720  1316.113284      0.0       56
# ...

# %%
df_rank = df_rank.drop(['train time', 'test time','minutes','seconds'], axis=1)
df_rank
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree   18.261076                6.856901    25.742938
# 1         Random_Forest   17.676717                6.637478    25.233405
# 2  HistGradientboosting   18.578334                6.976029    26.445477
# 3                   KNN   23.595346                8.859881    31.618577
# 4                   MLP   17.261067                6.481405    24.370805
# 5                 Ridge   20.480553                7.690299    28.229876
# 6               XGBoost   18.593861                6.981859    26.908556
# 7           CatBoosting   15.970150                5.996675    23.694468
#
#    Relative mse error (%) converted train time
# 0                9.666286             0.0p:28s
# 1                9.474960             3.0p:00s
# 2                9.930084             0.0p:56s
# 3               11.872545             0.0p:01s
# 4                9.151060             0.0p:02s
# ...

# %%
from google.colab import files

# Xuất dataframe ra file Excel
df_rank.to_excel('df_rank.xlsx', index=False)

# Tải file xuống máy
files.download('df_rank.xlsx')

# %% [markdown]
# # PV

# %%
# %cd '/content/drive/MyDrive/19_5_Results/PV/ALL'
# Out:
# /content/drive/MyDrive/19_5_Results/PV/ALL

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Đọc dữ liệu từ file pickle
def load_data(file_path):
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    return data

data_method1 = load_data('PV_GradientBoostingTree_all.pkl')
data_method2 = load_data('PV_RandomForest_all.pkl')
data_method3 = load_data('PV_CatBoosting_all.pkl')
data_method4 = load_data('PV_HistGradientBoosting_all.pkl')
data_method5 = load_data('PV_KNN_all.pkl')
data_method6 = load_data('PV_MLP_all.pkl')
data_method7 = load_data('PV_Ridge_all.pkl')
data_method8 = load_data('PV_XGBoost_all.pkl')


# Tạo bảng so sánh lỗi
methods = ['GradientBoostingtree', 'Random_Forest', 'CatBoosting','HistGradientboosting',
           'KNN','MLP','Ridge','XGBoost']
rmse = [data_method1['RMSE'], data_method2['RMSE'],
        data_method3['RMSE'], data_method4['RMSE'],
        data_method5['RMSE'], data_method6['RMSE'],
        data_method7['RMSE'], data_method8['RMSE']]

mse = [data_method1['MSE'], data_method2['MSE'],
       data_method3['MSE'], data_method4['MSE'],
       data_method5['MSE'], data_method6['MSE'],
       data_method7['MSE'], data_method8['MSE']]

mae = [data_method1['MAE'], data_method2['MAE'],
       data_method3['MAE'], data_method4['MAE'],
       data_method5['MAE'], data_method6['MAE'],
       data_method7['MAE'], data_method8['MAE']]

rel_mae =[data_method1['Relative MAE'], data_method2['Relative MAE'],
          data_method3['Relative MAE'], data_method4['Relative MAE'],
          data_method5['Relative MAE'], data_method6['Relative MAE'],
          data_method7['Relative MAE'], data_method8['Relative MAE']]

rel_rmse =[data_method1['Relative RMSE'], data_method2['Relative RMSE'],
           data_method3['Relative RMSE'], data_method4['Relative RMSE'],
           data_method5['Relative RMSE'], data_method6['Relative RMSE'],
           data_method7['Relative RMSE'], data_method8['Relative RMSE']]

train_time =[data_method1['train time'], data_method2['train time'],
             data_method3['train time'], data_method4['train time'],
             data_method5['train time'], data_method6['train time'],
             data_method7['train time'], data_method8['train time']]

test_time = [data_method1['test time'], data_method2['test time'],
             data_method3['test time'], data_method4['test time'],
             data_method5['test time'], data_method6['test time'],
             data_method7['test time'], data_method8['test time']]


df_rank = pd.DataFrame({
    'Method': methods,
    'MAE error ': mae,
    'Relative mae error (%)': rel_mae,
    'RRMSE error': rmse,
    'Relative mse error (%)': rel_rmse,
    'train time': train_time,
    'test time': test_time

})

print(df_rank)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree    9.405755                5.822694    13.453399
# 1         Random_Forest    9.765744                6.045547    14.279436
# 2           CatBoosting    8.481385                5.250457    12.499565
# 3  HistGradientboosting    8.619199                5.335771    12.622780
# 4                   KNN   11.196465                6.931244    15.593747
# 5                   MLP   10.519441                6.512128    14.897566
# 6                 Ridge   10.908082                6.752719    14.937446
# 7               XGBoost    8.984106                5.561670    13.005201
#
#    Relative mse error (%)    train time  test time
# 0                8.328414   1922.210036   0.011185
# 1                8.839778   2305.740852   0.145181
# 2                7.737937  15069.374071   0.014490
# 3                7.814214   1574.785286   0.165619
# 4                9.653411    306.457799   0.050578
# ...

# %%
import pandas as pd

# Giả sử bạn có một DataFrame với cột 'train time' tính bằng giây
# Tạo lại DataFrame từ df_rank nếu cần
df_rank = pd.DataFrame(df_rank)

# Tạo cột phút, giây, và mili giây
df_rank['minutes'] = df_rank['train time'] // 60
df_rank['seconds'] = (df_rank['train time'] % 60).astype(int)
df_rank['milliseconds'] = ((df_rank['train time'] % 1) * 1000).astype(int)

# Chuyển đổi thời gian đào tạo thành chuỗi có định dạng "phút:giây:ms"
df_rank['converted train time'] = (
    df_rank['minutes'].astype(str) + 'p:' +
    df_rank['seconds'].astype(str).str.zfill(2) + 's:' +
    df_rank['milliseconds'].astype(str).str.zfill(3) + 'ms'
)
df_rank['minutes'] = df_rank['test time'] // 60
df_rank['seconds'] = (df_rank['test time'] % 60).astype(int)
df_rank['milliseconds'] = ((df_rank['test time'] % 1) * 1000).astype(int)

df_rank['converted test time'] = (
    df_rank['minutes'].astype(str) + 'p:' +
    df_rank['seconds'].astype(str).str.zfill(2) + 's:' +
    df_rank['milliseconds'].astype(str).str.zfill(3) + 'ms'
)
# Hiển thị kết quả
print(df_rank)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree    9.405755                5.822694    13.453399
# 1         Random_Forest    9.765744                6.045547    14.279436
# 2           CatBoosting    8.481385                5.250457    12.499565
# 3  HistGradientboosting    8.619199                5.335771    12.622780
# 4                   KNN   11.196465                6.931244    15.593747
# 5                   MLP   10.519441                6.512128    14.897566
# 6                 Ridge   10.908082                6.752719    14.937446
# 7               XGBoost    8.984106                5.561670    13.005201
#
#    Relative mse error (%)    train time  test time  minutes  seconds  \
# 0                8.328414   1922.210036   0.011185      0.0        0
# 1                8.839778   2305.740852   0.145181      0.0        0
# 2                7.737937  15069.374071   0.014490      0.0        0
# ...

# %%
# %cd '/content/drive/MyDrive/19_5_Results/PV/Selected'
# Out:
# /content/drive/MyDrive/19_5_Results/PV/Selected

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Đọc dữ liệu từ file pickle
def load_data(file_path):
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    return data

data_method1 = load_data('PV_GradientBoostingTree_selected.pkl')
data_method2 = load_data('PV_RandomForest_selected.pkl')
data_method3 = load_data('PV_CatBoosting_selected.pkl')
data_method4 = load_data('PV_HistGradientBoosting_selected.pkl')
data_method5 = load_data('PV_KNN_selected.pkl')
data_method6 = load_data('PV_MLP_selected.pkl')
data_method7 = load_data('PV_Ridge_selected.pkl')
data_method8 = load_data('PV_XGBoost_selected.pkl')


# Tạo bảng so sánh lỗi
methods = ['GradientBoostingtree', 'Random_Forest', 'CatBoosting',
           'HistGradientboosting', 'KNN','MLP','Ridge','XGBoost']
rmse = [data_method1['RMSE'], data_method2['RMSE'],
        data_method3['RMSE'], data_method4['RMSE'],
        data_method5['RMSE'], data_method6['RMSE'], 
        data_method7['RMSE'], data_method8['RMSE']]

mse = [data_method1['MSE'], data_method2['MSE'],
       data_method3['MSE'], data_method4['MSE'],
       data_method5['MSE'], data_method6['MSE'], 
       data_method7['MSE'], data_method8['MSE']]

mae = [data_method1['MAE'], data_method2['MAE'],
       data_method3['MAE'], data_method4['MAE'],
       data_method5['MAE'], data_method6['MAE'], 
       data_method7['MAE'], data_method8['MAE']]

rel_mae =[data_method1['Relative MAE'], data_method2['Relative MAE'],
          data_method3['Relative MAE'], data_method4['Relative MAE'],
          data_method5['Relative MAE'], data_method6['Relative MAE'],
          data_method7['Relative MAE'], data_method8['Relative MAE']]

rel_rmse =[data_method1['Relative RMSE'], data_method2['Relative RMSE'],
           data_method3['Relative RMSE'], data_method4['Relative RMSE'],
           data_method5['Relative RMSE'], data_method6['Relative RMSE'], 
           data_method7['Relative RMSE'], data_method8['Relative RMSE']]

train_time =[data_method1['train time'], data_method2['train time'],
             data_method3['train time'], data_method4['train time'],
             data_method5['train time'], data_method6['train time'], 
             data_method7['train time'], data_method8['train time']]

test_time = [data_method1['test time'], data_method2['test time'],
             data_method3['test time'], data_method4['test time'],
             data_method5['test time'], data_method6['test time'], 
             data_method7['test time'], data_method8['test time']]


df_rank2 = pd.DataFrame({
    'Method': methods,
    'MAE error ': mae,
    'Relative mae error (%)': rel_mae,
    'RRMSE error': rmse,
    'Relative mse error (%)': rel_rmse,
    'train time': train_time,
    'test time': test_time

})

print(df_rank2)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree   10.373936                6.422053    14.842852
# 1         Random_Forest   10.102900                6.254266    14.754338
# 2           CatBoosting    9.582606                5.932175    14.035061
# 3  HistGradientboosting    9.853465                6.099852    14.225072
# 4                   KNN   10.762223                6.662424    15.120662
# 5                   MLP   10.413165                6.446338    14.853037
# 6                 Ridge   10.980077                6.797288    15.260167
# 7               XGBoost    9.853804                6.100061    14.329181
#
#    Relative mse error (%)    train time  test time
# 0                9.188564   1371.511380   0.010540
# 1                9.133769   1820.765034   0.160460
# 2                8.688496  24278.163989   0.015694
# 3                8.806123   1177.974592   0.448515
# 4                9.360544    319.791605   0.017248
# ...

# %%
import pandas as pd

# Giả sử bạn có một DataFrame với cột 'train time' tính bằng giây
# Tạo lại DataFrame từ df_rank nếu cần
df_rank2 = pd.DataFrame(df_rank2)

# Tạo cột phút, giây, và mili giây
df_rank2['minutes'] = df_rank2['train time'] // 60
df_rank2['seconds'] = (df_rank2['train time'] % 60).astype(int)
df_rank2['milliseconds'] = ((df_rank2['train time'] % 1) * 1000).astype(int)

# Chuyển đổi thời gian đào tạo thành chuỗi có định dạng "phút:giây:ms"
df_rank2['converted train time'] = (
    df_rank2['minutes'].astype(str) + 'p:' +
    df_rank2['seconds'].astype(str).str.zfill(2) + 's:' +
    df_rank2['milliseconds'].astype(str).str.zfill(3) + 'ms'
)
df_rank2['minutes'] = df_rank2['test time'] // 60
df_rank2['seconds'] = (df_rank2['test time'] % 60).astype(int)
df_rank2['milliseconds'] = ((df_rank2['test time'] % 1) * 1000).astype(int)

df_rank2['converted test time'] = (
    df_rank2['minutes'].astype(str) + 'p:' +
    df_rank2['seconds'].astype(str).str.zfill(2) + 's:' +
    df_rank2['milliseconds'].astype(str).str.zfill(3) + 'ms'
)
# Hiển thị kết quả
print(df_rank2)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree   10.373936                6.422053    14.842852
# 1         Random_Forest   10.102900                6.254266    14.754338
# 2           CatBoosting    9.582606                5.932175    14.035061
# 3  HistGradientboosting    9.853465                6.099852    14.225072
# 4                   KNN   10.762223                6.662424    15.120662
# 5                   MLP   10.413165                6.446338    14.853037
# 6                 Ridge   10.980077                6.797288    15.260167
# 7               XGBoost    9.853804                6.100061    14.329181
#
#    Relative mse error (%)    train time  test time  minutes  seconds  \
# 0                9.188564   1371.511380   0.010540      0.0        0
# 1                9.133769   1820.765034   0.160460      0.0        0
# 2                8.688496  24278.163989   0.015694      0.0        0
# ...

# %%
df_rank2 = df_rank2.drop(['train time', 'test time','minutes','seconds','milliseconds'], axis=1)
df_rank2
from google.colab import files

# Xuất dataframe ra file Excel
df_rank2.to_excel('df_rank.xlsx', index=False)

# Tải file xuống máy
files.download('df_rank.xlsx')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
target = 'PV '
# Tạo bảng màu thủ công để áp dụng cho tất cả các lần gọi scatterplot
palette = {
    'GradientBoostingtree': 'blue',
    'Random_Forest': 'red',
    'HistGradientboosting': 'green',
    'KNN': 'pink',
    'MLP': 'orange',
    'Ridge': 'brown',
    'XGBoost': 'purple',
    'CatBoosting': 'black'
}

plt.figure(figsize=(10, 7))

# Vẽ các scatterplot
sns.scatterplot(data=df_rank, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend="full")
sns.scatterplot(data=df_rank2, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend=False)

# Thêm chú thích tùy chỉnh ngắn gọn cho các kiểu marker
plt.scatter([], [], c='black', marker='o', label='All')
plt.scatter([], [], c='black', marker='X', label='Selected')


# Hiển thị chú thích với cỡ chữ nhỏ hơn
plt.legend(title="Markers", fontsize=10, title_fontsize=12, loc='upper right')
# Đặt tên cho trục và tiêu đề đồ thị
plt.xlabel("Running Time (s)", size=20)
plt.ylabel("Relative Error (MAE) %", size=20)
plt.title("Error vs Testing Time for " + target + " Forecast in 24 hours", size=20)

#plt.xlim(-0.05,0.15)
#plt.ylim(8,12)
# Hiển thị đồ thị
plt.show()
# Out:
# <ipython-input-45-46e54b1870a5>:19: UserWarning:
# The markers list has fewer values (1) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend="full")
# <ipython-input-45-46e54b1870a5>:20: UserWarning:
# The markers list has fewer values (1) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank2, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Tạo bảng màu thủ công để áp dụng cho tất cả các lần gọi scatterplot
palette = {
    'GradientBoostingtree': 'blue',
    'Random_Forest': 'red',
    'HistGradientboosting': 'green',
    'KNN': 'pink',
    'MLP': 'orange',
    'Ridge': 'brown',
    'XGBoost': 'purple',
    'CatBoosting': 'black'
}

plt.figure(figsize=(10, 7))

# Vẽ các scatterplot
sns.scatterplot(data=df_rank, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend="full")
sns.scatterplot(data=df_rank2, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend=False)

# Thêm chú thích tùy chỉnh ngắn gọn cho các kiểu marker
plt.scatter([], [], c='black', marker='o', label='All')
plt.scatter([], [], c='black', marker='X', label='Selected')


# Hiển thị chú thích với cỡ chữ nhỏ hơn
plt.legend(title="Markers", fontsize=10, title_fontsize=12, loc='upper right')
# Đặt tên cho trục và tiêu đề đồ thị
plt.xlabel("Running Time (s)", size=20)
plt.ylabel("Relative Error (RMSE) %", size=20)
plt.title("Error vs Testing Time for " + target + " Forecast in 24 hours", size=20)

# Hiển thị đồ thị
plt.show()
# Out:
# <ipython-input-47-1fb2dfdee97b>:19: UserWarning:
# The markers list has fewer values (1) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend="full")
# <ipython-input-47-1fb2dfdee97b>:20: UserWarning:
# The markers list has fewer values (1) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank2, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend=False)

# %%
df_rank = df_rank.drop(['train time', 'test time','minutes','seconds','milliseconds'], axis=1)
df_rank

# %%
from google.colab import files

# Xuất dataframe ra file Excel
df_rank.to_excel('df_rank.xlsx', index=False)

# Tải file xuống máy
files.download('df_rank.xlsx')

# %% [markdown]
# # Wind

# %%
# %cd '/content/drive/MyDrive/19_5_Results/WindTurbine/All'
# Out:
# /content/drive/MyDrive/19_5_Results/WindTurbine/All

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Đọc dữ liệu từ file pickle
def load_data(file_path):
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    return data
'''
'''
data_method1 = load_data('wind_GradientBoostingTree_all.pkl')
data_method2 = load_data('wind_RandomForest_all.pkl')
data_method3 = load_data('wind_CatBoosting_all.pkl')
data_method4 = load_data('wind_HistGradientBoosting_all.pkl')
data_method5 = load_data('wind_KNN_all.pkl')
data_method6 = load_data('wind_MLP_all.pkl')
data_method7 = load_data('wind_Ridge_all.pkl')
data_method8 = load_data('wind_XGBoost_all.pkl')
# Tạo bảng so sánh lỗi
methods = ['GradientBoostingtree', 'Random_Forest',
           'CatBoosting',
           'HistGradientboosting',
           'KNN','MLP','Ridge','XGBoost']
rmse = [data_method1['RMSE'], data_method2['RMSE'],
        data_method3['RMSE'], data_method4['RMSE'],
        data_method5['RMSE'], data_method6['RMSE'], 
        data_method7['RMSE'], data_method8['RMSE']]

mse = [data_method1['MSE'], data_method2['MSE'],
       data_method3['MSE'], data_method4['MSE'],
       data_method5['MSE'], data_method6['MSE'], 
       data_method7['MSE'], data_method8['MSE']]

mae = [data_method1['MAE'], data_method2['MAE'],
       data_method3['MAE'], data_method4['MAE'],
       data_method5['MAE'], data_method6['MAE'], 
       data_method7['MAE'], data_method8['MAE']]

rel_mae =[data_method1['Relative MAE'], data_method2['Relative MAE'],
          data_method3['Relative MAE'], data_method4['Relative MAE'],
          data_method5['Relative MAE'], data_method6['Relative MAE'], 
          data_method7['Relative MAE'], data_method8['Relative MAE']]

rel_rmse =[data_method1['Relative RMSE'], data_method2['Relative RMSE'],
           data_method3['Relative RMSE'], data_method4['Relative RMSE'],
           data_method5['Relative RMSE'], data_method6['Relative RMSE'], 
           data_method7['Relative RMSE'], data_method8['Relative RMSE']]

train_time =[data_method1['train time'], data_method2['train time'],
             data_method3['train time'], data_method4['train time'],
             data_method5['train time'], data_method6['train time'], 
             data_method7['train time'], data_method8['train time']]

test_time = [data_method1['test time'], data_method2['test time'],
             data_method3['test time'], data_method4['test time'],
             data_method5['test time'], data_method6['test time'], 
             data_method7['test time'], ddata_method8['test time']]


df_rank = pd.DataFrame({
    'Method': methods,
    'MAE error ': mae,
    'Relative mae error (%)': rel_mae,
    'RRMSE error': rmse,
    'Relative mse error (%)': rel_rmse,
    'train time': train_time,
    'test time': test_time

})

print(df_rank)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree   12.114333                7.148474    16.023600
# 1         Random_Forest   12.098687                7.139241    15.976399
# 2           CatBoosting   10.855389                6.405591    14.549529
# 3  HistGradientboosting   11.002055                6.492136    14.713105
# 4                   KNN   67.928543               40.083544    86.930045
# 5                   MLP   38.141404               22.506631    45.102539
# 6                 Ridge   35.040383               20.676769    42.779130
# 7               XGBoost   10.941850                6.456611    14.690112
#
#    Relative mse error (%)    train time  test time
# 0                9.455270   1408.689947   0.012852
# 1                9.427417   2003.024537   0.134833
# 2                8.585444  18382.779711   0.006897
# 3                8.681968   2033.108097   0.138692
# 4               51.296026    339.843699   0.055102
# ...

# %%
import pandas as pd

# Giả sử bạn có một DataFrame với cột 'train time' tính bằng giây
# Tạo lại DataFrame từ df_rank nếu cần
df_rank = pd.DataFrame(df_rank)

# Tạo cột phút, giây, và mili giây
df_rank['minutes'] = df_rank['train time'] // 60
df_rank['seconds'] = (df_rank['train time'] % 60).astype(int)
df_rank['milliseconds'] = ((df_rank['train time'] % 1) * 1000).astype(int)

# Chuyển đổi thời gian đào tạo thành chuỗi có định dạng "phút:giây:ms"
df_rank['converted train time'] = (
    df_rank['minutes'].astype(str) + 'p:' +
    df_rank['seconds'].astype(str).str.zfill(2) + 's:' +
    df_rank['milliseconds'].astype(str).str.zfill(3) + 'ms'
)
df_rank['minutes'] = df_rank['test time'] // 60
df_rank['seconds'] = (df_rank['test time'] % 60).astype(int)
df_rank['milliseconds'] = ((df_rank['test time'] % 1) * 1000).astype(int)

df_rank['converted test time'] = (
    df_rank['minutes'].astype(str) + 'p:' +
    df_rank['seconds'].astype(str).str.zfill(2) + 's:' +
    df_rank['milliseconds'].astype(str).str.zfill(3) + 'ms'
)
# Hiển thị kết quả
print(df_rank)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree   12.114333                7.148474    16.023600
# 1         Random_Forest   12.098687                7.139241    15.976399
# 2           CatBoosting   10.855389                6.405591    14.549529
# 3  HistGradientboosting   11.002055                6.492136    14.713105
# 4                   KNN   67.928543               40.083544    86.930045
# 5                   MLP   38.141404               22.506631    45.102539
# 6                 Ridge   35.040383               20.676769    42.779130
# 7               XGBoost   10.941850                6.456611    14.690112
#
#    Relative mse error (%)    train time  test time  minutes  seconds  \
# 0                9.455270   1408.689947   0.012852      0.0        0
# 1                9.427417   2003.024537   0.134833      0.0        0
# 2                8.585444  18382.779711   0.006897      0.0        0
# ...

# %%
from google.colab import files

# Xuất dataframe ra file Excel
df_rank2.to_excel('df_rank.xlsx', index=False)

# Tải file xuống máy
files.download('df_rank.xlsx')

# %%
# %cd '/content/drive/MyDrive/19_5_Results/WindTurbine/Selected'
# Out:
# /content/drive/MyDrive/19_5_Results/WindTurbine/Selected

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Đọc dữ liệu từ file pickle
def load_data(file_path):
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    return data
'''
data_method1 = load_data('wind_GradientBoostingTree_all.pkl')
data_method2 = load_data('wind_RandomForest_all.pkl')
data_method3 = load_data('wind_CatBoosting_all.pkl')
data_method4 = load_data('wind_HistGradientBoosting_all.pkl')
data_method5 = load_data('wind_KNN_all.pkl')
data_method6 = load_data('wind_MLP_all.pkl')
data_method7 = load_data('wind_Ridge_all.pkl')
data_method8 = load_data('wind_XGBoost_all.pkl')
'''
data_method1 = load_data('wind_GradientBoostingTree_selected.pkl')
data_method2 = load_data('wind_RandomForest_selected.pkl')
data_method3 = load_data('wind_CatBoosting_selected.pkl')
data_method4 = load_data('wind_HistGradientBoosting_selected.pkl')
data_method5 = load_data('wind_KNN_selected.pkl')
data_method6 = load_data('wind_MLP_selected.pkl')
data_method7 = load_data('wind_Ridge_selected.pkl')
data_method8 = load_data('wind_XGBoost_selected.pkl')
# Tạo bảng so sánh lỗi
methods = ['GradientBoostingtree', 'Random_Forest', 'CatBoosting',
           'HistGradientboosting',
           'KNN','MLP','Ridge','XGBoost']
rmse = [data_method1['RMSE'], data_method2['RMSE'],
        data_method3['RMSE'], data_method4['RMSE'],
        data_method5['RMSE'], data_method6['RMSE'], 
        data_method7['RMSE'], data_method8['RMSE']]

mse = [data_method1['MSE'], data_method2['MSE'],
       data_method3['MSE'], data_method4['MSE'],
       data_method5['MSE'], data_method6['MSE'], 
       data_method7['MSE'], data_method8['MSE']]

mae = [data_method1['MAE'], data_method2['MAE'],
       data_method3['MAE'], data_method4['MAE'],
       data_method5['MAE'], data_method6['MAE'], 
       data_method7['MAE'], data_method8['MAE']]

rel_mae =[data_method1['Relative MAE'], data_method2['Relative MAE'],
          data_method3['Relative MAE'], data_method4['Relative MAE'],
          data_method5['Relative MAE'], data_method6['Relative MAE'], 
          data_method7['Relative MAE'], data_method8['Relative MAE']]

rel_rmse =[data_method1['Relative RMSE'], data_method2['Relative RMSE'],
           data_method3['Relative RMSE'], data_method4['Relative RMSE'],
           data_method5['Relative RMSE'], data_method6['Relative RMSE'], 
           data_method7['Relative RMSE'], data_method8['Relative RMSE']]

train_time =[data_method1['train time'], data_method2['train time'],
             data_method3['train time'], data_method4['train time'],
             data_method5['train time'], data_method6['train time'], 
             data_method7['train time'], data_method8['train time']]

test_time = [data_method1['test time'], data_method2['test time'],
             data_method3['test time'], data_method4['test time'],
             data_method5['test time'], data_method6['test time'], 
             data_method7['test time'], data_method8['test time']]


df_rank2 = pd.DataFrame({
    'Method': methods,
    'MAE error ': mae,
    'Relative mae error (%)': rel_mae,
    'RRMSE error': rmse,
    'Relative mse error (%)': rel_rmse,
    'train time': train_time,
    'test time': test_time

})

print(df_rank2)
# Out:
#                  Method  MAE error   Relative mae error (%)  RRMSE error  \
# 0  GradientBoostingtree   13.348899                7.876971    17.698354
# 1         Random_Forest   13.298884                7.847458    17.609999
# 2           CatBoosting   13.040446                7.694958    17.285558
# 3  HistGradientboosting   13.278068                7.835175    17.601544
# 4                   KNN   13.155233                7.762692    17.526646
# 5                   MLP   13.052187                7.701886    17.312777
# 6                 Ridge   36.852279               21.745939    45.357706
# 7               XGBoost   13.266079                7.828101    17.521736
#
#    Relative mse error (%)   train time  test time
# 0               10.443515   505.096005   0.010741
# 1               10.391378   682.270993   0.062232
# 2               10.199931  5052.211672   0.002659
# 3               10.386389   838.538000   0.048278
# 4               10.342193   263.518492   0.019934
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
target = 'P_wind'
# Tạo bảng màu thủ công để áp dụng cho tất cả các lần gọi scatterplot
palette = {
    'GradientBoostingtree': 'blue',
    'Random_Forest': 'red',
    'HistGradientboosting': 'green',
    'KNN': 'pink',
    'MLP': 'orange',
    'Ridge': 'brown',
    'XGBoost': 'purple',
    'CatBoosting': 'black'
}

plt.figure(figsize=(10, 7))

# Vẽ các scatterplot
sns.scatterplot(data=df_rank, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend="full")
sns.scatterplot(data=df_rank2, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend=False)
#sns.scatterplot(data=df_rank3, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="^", s=100, palette=palette, legend=False)
# Thêm chú thích tùy chỉnh ngắn gọn cho các kiểu marker
plt.scatter([], [], c='black', marker='o', label='All')
plt.scatter([], [], c='black', marker='X', label='Selected')
#plt.scatter([], [], c='black', marker='X', label='exog only')

# Hiển thị chú thích với cỡ chữ nhỏ hơn
plt.legend(title="Markers", fontsize=10, title_fontsize=12, loc='upper right')
# Đặt tên cho trục và tiêu đề đồ thị
plt.xlabel("Running Time (s)", size=20)
plt.ylabel("Relative Error (MAE) %", size=20)
plt.title("Error vs Testing Time for " + target + " Forecast in 24 hours", size=20)

#plt.xlim(-0.025,0.15)
#plt.ylim(6,12)
# Hiển thị đồ thị
plt.show()
# Out:
# <ipython-input-8-467ac4018587>:19: UserWarning:
# The markers list has fewer values (1) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend="full")
# <ipython-input-8-467ac4018587>:20: UserWarning:
# The markers list has fewer values (1) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank2, x="test time", y="Relative mae error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Tạo bảng màu thủ công để áp dụng cho tất cả các lần gọi scatterplot
palette = {
    'GradientBoostingtree': 'blue',
    'Random_Forest': 'red',
    'HistGradientboosting': 'green',
    'KNN': 'pink',
    'MLP': 'orange',
    'Ridge': 'brown',
    'XGBoost': 'purple',
    'CatBoosting': 'black'
}

plt.figure(figsize=(10, 7))

# Vẽ các scatterplot
sns.scatterplot(data=df_rank, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend="full")
sns.scatterplot(data=df_rank2, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend=False)

# Thêm chú thích tùy chỉnh ngắn gọn cho các kiểu marker
plt.scatter([], [], c='black', marker='o', label='All')
plt.scatter([], [], c='black', marker='X', label='Selected')


# Hiển thị chú thích với cỡ chữ nhỏ hơn
plt.legend(title="Markers", fontsize=10, title_fontsize=12, loc='upper right')
# Đặt tên cho trục và tiêu đề đồ thị
plt.xlabel("Running Time (s)", size=20)
plt.ylabel("Relative Error (RMSE) %", size=20)
plt.title("Error vs Testing Time for " + target + " Forecast in 24 hours", size=20)

#plt.xlim(-0.025,0.15)
#plt.ylim(9,15)
# Hiển thị đồ thị
plt.show()
# Out:
# <ipython-input-9-837f7350fd91>:19: UserWarning:
# The markers list has fewer values (1) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="X", s=100, palette=palette, legend="full")
# <ipython-input-9-837f7350fd91>:20: UserWarning:
# The markers list has fewer values (1) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df_rank2, x="test time", y="Relative mse error (%)", hue="Method", style="Method", markers="o", s=100, palette=palette, legend=False)
